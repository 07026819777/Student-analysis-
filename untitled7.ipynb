# %% [markdown]
# <a href="https://colab.research.google.com/github/07026819777/Student-analysis-/blob/main/untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = str("abubakar Jibril yanda")
print(name)
age = int("23")
print (age)
department=str("biology education")
print (department)
mathematics=float ("75")
print (mathematics)
Python=float ("82")
print (Python)
statistics=float ("68")
print (statistics)
total_score = mathematics + Python + statistics
print (total_score)
average_score = total_score/ 3
print(average_score)
highest_score=max(mathematics, Python, statistics)
print(highest_score)
lowest_score=min(mathematics, Python, statistics)
print (lowest_score)
passed=average_score>=50
print (passed)
# Out:
# abubakar Jibril yanda
# 23
# biology education
# 75.0
# 82.0
# 68.0
# 225.0
# 75.0
# 82.0
# 68.0
# True
